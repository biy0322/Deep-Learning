# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # SGD OPtimizer

# %%
with open("/content/drive/MyDrive/Colab Notebooks/data/pickle/SGD.pickle", 'rb') as f:
  SGD = pickle.load(f)

# %%
len(SGD)
# Out:
# 900

# %% [markdown]
# - batch_size가 60인 데이터를 15번 학습
# - 15*60 = 900

# %% [markdown]
# # Adam Optimizer

# %%
with open("/content/drive/MyDrive/Colab Notebooks/data/pickle/ADAM.pickle", 'rb') as f:
  ADAM = pickle.load(f)

# %% [markdown]
# # Dropout

# %%
with open("/content/drive/MyDrive/Colab Notebooks/data/pickle/Dropout.pickle", 'rb') as f:
  dropout = pickle.load(f)

# %% [markdown]
# # BatchNormalization

# %%
with open("/content/drive/MyDrive/Colab Notebooks/data/pickle/BatchNorm.pickle", 'rb') as f:
  batchnormalization = pickle.load(f)

# %% [markdown]
# # Loss

# %%
plt.figure(figsize=(15, 10))

plt.plot(np.array(SGD[17:]), 'g', label='SGD')
plt.plot(np.array(ADAM[17:]), 'r', label='Adam')
plt.plot(np.array(dropout[17:]), 'y', label='Dropout')
plt.plot(np.array(batchnormalization[17:]), 'k', label='BatchNorm')

plt.legend()

plt.grid('on')

plt.show()
